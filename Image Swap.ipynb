# %%
import cv2
import matplotlib.pyplot as plt
import time
import numpy as np

# %%
image = cv2.imread("Menu.jpeg")
resized_image = cv2.resize(image, (500, 700))
plt.imshow(resized_image)

# %%
#cv2.rectangle(resized_image,(30,380),(120,460),(255,0,0))
#cv2.rectangle(resized_image,(380,380),(470,460),(0,255,0))

# %%
cv2.imshow("Menu", resized_image)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
part1 = resized_image[380:460,30:120].copy()
part2 = resized_image[380:460,380:470].copy()

# %%
cv2.imshow("Menu", part1)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
resized_image[380:460,30:120] = part2
resized_image[380:460,380:470] = part1

# %%
cv2.imshow("Menu", resized_image)
cv2.waitKey()
cv2.destroyAllWindows()
